# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
df_clean=pd.read_csv(r"C:\Users\Dima\Downloads\Dima\Cleaned_df.csv",dtype={'col':np.float})
df_clean.rename(columns={'Unnamed: 0':'Causes'},inplace=True)
df_clean.set_index('Causes',inplace=True)
df_clean.drop('Unnamed: 8',axis=1,inplace=True)
for i in df_clean.columns:
    print(i)
# Out:
# Alcohol
# All Cancers
# Alzheimers & Dementia
# Anemia
# Asthma
# Birth Trauma
# Bladder Cancer
# Breast Cancer
# Cervical Cancer
# Colon-Rectum Cancers
# Congenital Anomalies
# Coronary Heart Disease
# Diabetes Mellitus
# Diarrhoeal diseases
# Drownings
# Drug Use
# Endocrine Disorders
# Falls
# Fires
# Hepatitis C
# HIV/AIDS
# Hypertension
# Inflammatory/Heart
# Kidney Disease
# Leukemia
# Liver Cancer
# Liver Disease
# Low Birth Weight
# Lung Cancers
# Lung Disease
# Malaria
# Malnutrition
# Multiple Sclerosis
# Oesophagus Cancer
# Oral Cancer
# Other Injuries
# Other Neoplasms
# Ovary Cancer
# Pancreas Cancer
# Peptic Ulcer Disease
# Poisonings
# Prostate Cancer
# Rheumatic Heart Disease
# Road Traffic Accidents
# Skin Cancers
# Skin Disease
# Stomach Cancer
# Stroke
# Suicide
# Tuberculosis
# Uterin Cancer
# Electricity by Renewable Sources
# Urban Population Growth Rates
# Infant Mortality Rates
# Natural Gas Imports
# Internet Users
# Gross Domestic Product (GDP)
# ...

# %%
fig, axes = plt.subplots(1 ,figsize=(20,5))
less_sixty=(df_clean['Life Expectancy']).sort_values(ascending=False)
vector_i=less_sixty.iloc[0:15]
axes.bar(height=vector_i  ,x=vector_i.index)
less_sixty
# Out:
# Causes
# Japan                       84.910
# Switzerland                 84.112
# Singapore                   83.934
# Spain                       83.864
# Italy                       83.856
#                              ...
# Sierra Leone                55.550
# Nigeria                     55.436
# Lesotho                     55.222
# Chad                        54.896
# Central African Republic    54.022
# Name: Life Expectancy, Length: 173, dtype: float64

# %%
fig, axes = plt.subplots(1 ,figsize=(20,5))
High=(df_clean['Life Expectancy']).sort_values(ascending=True)
vector_i=High.iloc[0:15]
axes.bar(height=vector_i  ,x=vector_i.index)
vector_i
# Out:
# Causes
# Central African Republic    54.022
# Chad                        54.896
# Lesotho                     55.222
# Nigeria                     55.436
# Sierra Leone                55.550
# Somalia                     58.060
# South Sudan                 58.476
# Guinea Bissau               59.068
# Cameroon                    60.010
# Mali                        60.174
# Mozambique                  61.714
# Togo                        61.810
# Angola                      61.884
# Zimbabwe                    61.894
# Guinea                      62.320
# Name: Life Expectancy, dtype: float64

# %%
value_Israel = df_clean.iloc[127]['Obesity Rates by Country']
value_Chad = df_clean.iloc[77]['Obesity Rates by Country']
df = pd.DataFrame({'Country':['Israel', 'Chad'], 'Obeisty_rate':[value_Israel,value_Chad]})
ax = df.plot.bar(x='Country', y='Obeisty_rate', rot=0)

# %%
fig, axes = plt.subplots(1 ,figsize=(20,5))
Suicide_rate=(df_clean['Suicide']).sort_values(ascending=False)
vector_i=Suicide_rate.iloc[50:60]
axes.pie(x=vector_i, labels=vector_i.index, autopct='%1.1f%%')
Suicide_rate
# Out:
# Causes
# India                  453193.440034
# Nigeria                204346.174576
# Indonesia               93873.304668
# Pakistan                51269.112114
# Bangladesh              42621.612320
#                            ...
# Malta                       0.574006
# Antigua And Barbuda         0.509231
# Bahamas                     0.314595
# Seychelles                  0.000000
# Iceland                     0.000000
# Name: Suicide, Length: 173, dtype: float64

# %%
fig, axes = plt.subplots(1 ,figsize=(20,5))
High=(df_clean['Obesity Rates by Country']).sort_values(ascending=False)
vector_i=High.iloc[0:15]
axes.bar(height=vector_i  ,x=vector_i.index)
vector_i
# Out:
# Causes
# Tonga                   0.482
# Samoa                   0.473
# Kiribati                0.460
# Kuwait                  0.379
# United States           0.362
# Jordan                  0.355
# Saudi Arabia            0.354
# Qatar                   0.351
# Lebanon                 0.337
# Libya                   0.325
# Turkey                  0.321
# Egypt                   0.320
# United Arab Emirates    0.317
# Bahamas                 0.316
# New Zealand             0.308
# Name: Obesity Rates by Country, dtype: float64

# %%
fig, axes = plt.subplots(1 ,figsize=(20,5))
High=(df_clean['Obesity Rates by Country']).sort_values(ascending=False)
vector_i=High.iloc[0:15]
axes.pie(x=vector_i, labels=vector_i.index, autopct='%1.1f%%')
vector_i
# Out:
# Causes
# Tonga                   0.482
# Samoa                   0.473
# Kiribati                0.460
# Kuwait                  0.379
# United States           0.362
# Jordan                  0.355
# Saudi Arabia            0.354
# Qatar                   0.351
# Lebanon                 0.337
# Libya                   0.325
# Turkey                  0.321
# Egypt                   0.320
# United Arab Emirates    0.317
# Bahamas                 0.316
# New Zealand             0.308
# Name: Obesity Rates by Country, dtype: float64

# %%
fig, axes = plt.subplots(1 ,figsize=(20,5))
High=(df_clean['Countries by IQ - Average IQ by Country']).sort_values(ascending=False)
vector_i=High.iloc[0:15]
axes.bar(height=vector_i  ,x=vector_i.index)
High
# Out:
# Causes
# Japan            106.48
# Singapore        105.89
# China            104.10
# South Korea      102.35
# Belarus          101.60
#                   ...
# Guatemala         47.72
# Liberia           45.07
# Sierra Leone      45.07
# Nepal             42.99
# Guinea Bissau       NaN
# Name: Countries by IQ - Average IQ by Country, Length: 173, dtype: float64

# %%
df_clean.iloc[128]
data_israel=['Countries by IQ - Average IQ by Country','Median Age ','Life Expectancy','Obesity Rates by Country']
data_value=[]
for i in data_israel:
    data_value.append(df_clean.iloc[128][i])

fig, axes = plt.subplots(1 ,figsize=(20,5))
axes.bar(height=data_value  ,x=data_israel)
# Out:
# <BarContainer object of 4 artists>

# %%
data_Chad=['Countries by IQ - Average IQ by Country','Median Age ','Life Expectancy','Obesity Rates by Country']
Chad_value=[]
for i in data_israel:
    Chad_value.append(df_clean.iloc[77][i])
    
fig, axes = plt.subplots(1 ,figsize=(20,5))
axes.bar(height=Chad_value  ,x=data_Chad)
#Compres israel between the lowest life expectancy that is chad by the data we scraped
# Out:
# <BarContainer object of 4 artists>

# %%
indexs=[127,77]
resons_check = [
         'Countries by IQ - Average IQ by Country',
         'Life Expectancy']
ched_values=[]
israel_values=[]
for i in indexs:
    for j in resons_check:
        if(i==127):
            israel_values.append(df_clean.iloc[i][j])
        else:
            ched_values.append(df_clean.iloc[i][j])
  


           
df = pd.DataFrame({'Israel': israel_values,"Chad":ched_values}, index=resons_check)
ax = df.plot.barh()

# %%
indexs=[149,77]
resons_check = [
         'Countries by IQ - Average IQ by Country',
         'Life Expectancy']
ched_values=[]
japan_values=[]
for i in indexs:
    for j in resons_check:
        if(i==149):
            japan_values.append(df_clean.iloc[i][j])
        else:
            ched_values.append(df_clean.iloc[i][j])
  


           
df = pd.DataFrame({'japan': japan_values,"Chad":ched_values}, index=resons_check)
ax = df.plot.barh()

# %%
fig, axes = plt.subplots(1 ,figsize=(20,5))
High=(df_clean['Alcohol']).sort_values(ascending=True)
vector_i=High.iloc[0:15]
axes.bar(height=vector_i  ,x=vector_i.index)
vector_i
# Out:
# Causes
# Antigua And Barbuda    118.621398
# Seychelles             158.496025
# Tonga                  162.654035
# Grenada                174.691958
# Saint Lucia            185.426545
# Kiribati               210.970824
# Vanuatu                235.180927
# Samoa                  267.025561
# Iceland                357.383794
# Belize                 368.442105
# Barbados               402.468687
# Bahamas                416.799316
# Maldives               426.110835
# Malta                  458.454097
# Solomon Islands        578.631082
# Name: Alcohol, dtype: float64

# %%
fig, axes = plt.subplots(1 ,figsize=(20,5))
High=(df_clean['All Cancers']).sort_values(ascending=True)
vector_i=High.iloc[0:15]
axes.bar(height=vector_i  ,x=vector_i.index)
vector_i
# Out:
# Causes
# Antigua And Barbuda     6.003048
# Grenada                 7.775339
# Seychelles             16.935353
# Tonga                  18.993392
# Singapore              25.156471
# Armenia                25.780214
# Guyana                 25.798906
# Kiribati               30.172817
# Mauritius              30.649609
# Saint Lucia            31.436942
# Samoa                  37.956598
# Barbados               41.324525
# North Macedonia        44.792541
# Vanuatu                54.118949
# Bulgaria               54.892716
# Name: All Cancers, dtype: float64

# %%
fig, axes = plt.subplots(1 ,figsize=(20,5))
High=(df_clean['Cheapest Countries To Live in']).sort_values(ascending=True)
vector_i=High.iloc[0:15]
axes.bar(height=vector_i  ,x=vector_i.index)
vector_i
# Out:
# Causes
# Afghanistan    354.0
# Pakistan       370.0
# India          423.0
# Tunisia        424.0
# Sri Lanka      428.0
# Kyrgyzstan     430.0
# Algeria        431.0
# Syria          435.0
# Nepal          439.0
# Turkey         447.0
# Egypt          449.0
# Tajikistan     450.0
# Kazakhstan     468.0
# Argentina      494.0
# Belarus        504.0
# Name: Cheapest Countries To Live in, dtype: float64

# %%
fig, axes = plt.subplots(1 ,figsize=(20,5))
High=(df_clean['Birth Rate by Country']).sort_values(ascending=True)
vector_i=High.iloc[0:15]
axes.bar(height=vector_i  ,x=vector_i.index)
vector_i
# Out:
# Causes
# Japan             8.0
# Portugal          8.2
# South Korea       8.3
# Greece            8.3
# Italy             8.5
# Bulgaria          8.5
# Germany           8.6
# Singapore         8.7
# Romania           8.7
# Croatia           8.8
# Hungary           8.9
# Serbia            8.9
# Spain             9.0
# Slovenia          9.2
# Czech Republic    9.2
# Name: Birth Rate by Country, dtype: float64

# %%
fig, axes = plt.subplots(1 ,figsize=(20,5))
High=(df_clean['Autism Rates by Country']).sort_values(ascending=True)
vector_i=High.iloc[0:15]
axes.bar(height=vector_i  ,x=vector_i.index)
vector_i
# Out:
# Causes
# France         69.3
# Portugal       70.5
# Iceland        71.9
# Norway         72.0
# Italy          72.0
# Germany        72.2
# Greece         72.4
# Austria        72.6
# Belgium        73.0
# Spain          73.0
# Finland        73.2
# Netherlands    73.8
# Switzerland    73.8
# Denmark        73.8
# Cyprus         73.9
# Name: Autism Rates by Country, dtype: float64
