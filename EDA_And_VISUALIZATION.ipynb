# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
df_not_clean=pd.read_csv(r"C:\Users\Dima\Downloads\Jupyter_projectes\Untitled Folder 3\EDA_Viz\final_df.csv",dtype={'col':np.float})
df_clean=pd.read_csv(r"C:\Users\Dima\Downloads\Jupyter_projectes\Finshed_Machine learning\EDA_Viz\Cleaned_df.csv",dtype={'col':np.float})
df_not_clean.drop(['Unnamed: 0'],axis=1,inplace=True)
df_not_clean.rename(columns={'Unnamed: 0.1':'Causes'},inplace=True)
df_not_clean.set_index('Causes',inplace=True)
df_not_clean=df_not_clean.T


df_clean.rename(columns={'Unnamed: 0':'Causes'},inplace=True)
df_clean.set_index('Causes',inplace=True)
for i in df_clean.columns:
    print(i)
# Out:
# Alcohol
# Alzheimers & Dementia
# Anemia
# Asthma
# Birth Trauma
# Bladder Cancer
# Breast Cancer
# Cervical Cancer
# Colon-Rectum Cancers
# Congenital Anomalies
# Coronary Heart Disease
# Diabetes Mellitus
# Diarrhoeal diseases
# Drownings
# Drug Use
# Endocrine Disorders
# Falls
# Fires
# Hepatitis C
# HIV/AIDS
# Hypertension
# Inflammatory/Heart
# Kidney Disease
# Leukemia
# Liver Cancer
# Liver Disease
# Low Birth Weight
# Lung Cancers
# Lung Disease
# Malaria
# Malnutrition
# Multiple Sclerosis
# Oesophagus Cancer
# Oral Cancer
# Ovary Cancer
# Pancreas Cancer
# Peptic Ulcer Disease
# Poisonings
# Prostate Cancer
# Rheumatic Heart Disease
# Road Traffic Accidents
# Skin Cancers
# Skin Disease
# Stomach Cancer
# Stroke
# Suicide
# Tuberculosis
# Uterin Cancer
# Labor Force
# Electricity Production
# Petroleum Consumption
# Total Fertility Rates
# Young Population
# Natural Gas Consumption
# Infant Mortality Rates
# Natural Gas Production
# Taxes
# Maternal Mortality Rates
# Gross Domestic Product (GDP)
# Imports
# Older Population
# Carbon Dioxide Emissions
# Obesity
# Nuclear Electricity
# Electricity by Renewable Sources
# Natural Gas Imports
# Population
# Median Age
# Unimproved Drinking Water Sources
# Crude Oil Exports
# Hydro Electricity
# Electricity Consumption
# Inflation Rates
# External Debts
# Crude Oil Imports
# Birth Rates
# Deaths per Day
# Life Expectancy
# Emerging Countries
# Global North Countries
# Global South Countries
# Medical Bankruptcies by Country
# Richest Countries in the World
# Social Mobility by Country
# Countries by IQ - Average IQ by Country
# Diabetes Rates by Country
# Health Care Costs by Country
# Lactose Intolerance by Country
# Obesity Rates by Country
# Zika Virus Countries

# %%
df_not_clean
# Out:
# Causes                    Alcohol All Cancers Alzheimers & Dementia Anemia  \
# Belarus                    119.03       15.86                   0.0   0.72
# Mongolia                   194.38       17.63                   0.0   6.03
# Russia                     129.19       15.07                   0.0   0.72
# Guatemala                   82.54       16.66                   0.0   2.78
# Slovenia                   134.52         5.8                  0.01   0.23
# ...                           ...         ...                   ...    ...
# Saint Kitts And Nevis         NaN         NaN                   NaN    NaN
# Turks And Caicos Islands      NaN         NaN                   NaN    NaN
# Saint Martin                  NaN         NaN                   NaN    NaN
# Wallis And Futuna             NaN         NaN                   NaN    NaN
# Saint Pierre And Miquelon     NaN         NaN                   NaN    NaN
#
# Causes                    Asthma Birth Trauma Bladder Cancer   NaN  \
# Belarus                      0.4          1.7         676.27  1.46
# Mongolia                    2.96         1.04        1062.04  9.43
# Russia                      0.56         2.41         727.47  3.67
# Guatemala                   4.47         0.52         732.92  8.86
# Slovenia                     0.1         3.74         386.06  0.89
# ...                          ...          ...            ...   ...
# Saint Kitts And Nevis        NaN          NaN            NaN   NaN
# Turks And Caicos Islands     NaN          NaN            NaN   NaN
# Saint Martin                 NaN          NaN            NaN   NaN
# Wallis And Futuna            NaN          NaN            NaN   NaN
# Saint Pierre And Miquelon    NaN          NaN            NaN   NaN
#
# Causes                    Breast Cancer Cervical Cancer  ...  \
# Belarus                            2.21           17.05  ...
# Mongolia                            6.3            4.43  ...
# Russia                             3.64           16.55  ...
# Guatemala                          7.09             4.1  ...
# Slovenia                           1.54           14.88  ...
# ...                                 ...             ...  ...
# Saint Kitts And Nevis               NaN             NaN  ...
# Turks And Caicos Islands            NaN             NaN  ...
# Saint Martin                        NaN             NaN  ...
# Wallis And Futuna                   NaN             NaN  ...
# Saint Pierre And Miquelon           NaN             NaN  ...
#
# Causes                    Countries With Negative Interest Rates  \
# Belarus                                                      NaN
# Mongolia                                                     NaN
# Russia                                                       NaN
# Guatemala                                                    NaN
# Slovenia                                                     NaN
# ...                                                          ...
# Saint Kitts And Nevis                                        NaN
# Turks And Caicos Islands                                     NaN
# Saint Martin                                                 NaN
# Wallis And Futuna                                            NaN
# Saint Pierre And Miquelon                                    NaN
#
# Causes                    Low Income Countries Sanctioned Countries  \
# Belarus                                    NaN                  NaN
# Mongolia                                   NaN                  NaN
# Russia                                     NaN                  NaN
# Guatemala                                  NaN                  NaN
# Slovenia                                   NaN                  NaN
# ...                                        ...                  ...
# Saint Kitts And Nevis                      NaN                  NaN
# Turks And Caicos Islands                   NaN                  NaN
# Saint Martin                               NaN                  NaN
# Wallis And Futuna                          NaN                  NaN
# Saint Pierre And Miquelon                  NaN                  NaN
#
# Causes                    Cheapest European Countries  \
# Belarus                                           NaN
# Mongolia                                          NaN
# Russia                                            NaN
# Guatemala                                         NaN
# Slovenia                                            X
# ...                                               ...
# Saint Kitts And Nevis                             NaN
# Turks And Caicos Islands                          NaN
# Saint Martin                                      NaN
# Wallis And Futuna                                 NaN
# Saint Pierre And Miquelon                         NaN
#
# Causes                    Countries That Use the Euro EEA Countries  \
# Belarus                                           NaN           NaN
# Mongolia                                          NaN           NaN
# Russia                                            NaN           NaN
# Guatemala                                         NaN           NaN
# Slovenia                                    2,078,034     2,078,034
# ...                                               ...           ...
# Saint Kitts And Nevis                             NaN           NaN
# Turks And Caicos Islands                          NaN           NaN
# Saint Martin                                      NaN           NaN
# Wallis And Futuna                                 NaN           NaN
# Saint Pierre And Miquelon                         NaN           NaN
#
# Causes                    Tax-Free Countries Traditional Economy Countries  \
# Belarus                                  NaN                           NaN
# Mongolia                                 NaN                           NaN
# Russia                                   NaN                           NaN
# Guatemala                                NaN                           NaN
# Slovenia                                 NaN                           NaN
# ...                                      ...                           ...
# Saint Kitts And Nevis                 53,871                           NaN
# Turks And Caicos Islands                 NaN                           NaN
# Saint Martin                             NaN                           NaN
# Wallis And Futuna                        NaN                           NaN
# Saint Pierre And Miquelon                NaN                           NaN
#
# Causes                    EFTA Countries | European Free Trade Association  \
# Belarus                                                                NaN
# Mongolia                                                               NaN
# Russia                                                                 NaN
# Guatemala                                                              NaN
# Slovenia                                                               NaN
# ...                                                                    ...
# Saint Kitts And Nevis                                                  NaN
# Turks And Caicos Islands                                               NaN
# Saint Martin                                                           NaN
# Wallis And Futuna                                                      NaN
# Saint Pierre And Miquelon                                              NaN
#
# Causes                    Countries Without Central Banks
# Belarus                                               NaN
# Mongolia                                              NaN
# Russia                                                NaN
# Guatemala                                             NaN
# Slovenia                                              NaN
# ...                                                   ...
# Saint Kitts And Nevis                                 NaN
# Turks And Caicos Islands                              NaN
# Saint Martin                                          NaN
# Wallis And Futuna                                     NaN
# Saint Pierre And Miquelon                             NaN
#
# [287 rows x 267 columns]

# %%
df_clean
# Out:
#            Alcohol  Alzheimers & Dementia  Anemia  Asthma  Birth Trauma  \
# Causes
# Belarus     119.03                   0.00    0.72    0.40          1.70
# Mongolia    194.38                   0.00    6.03    2.96          1.04
# Russia      129.19                   0.00    0.72    0.56          2.41
# Guatemala    82.54                   0.00    2.78    4.47          0.52
# Slovenia    134.52                   0.01    0.23    0.10          3.74
# ...            ...                    ...     ...     ...           ...
# Jordan      103.93                   0.00    2.17    1.77          4.28
# Venezuela    94.22                   0.46    1.13    3.10          1.35
# Singapore    90.81                   0.00    0.45    0.07          1.40
# Armenia     126.92                   0.12    0.23    1.15          4.25
# Colombia     84.23                   0.18    0.36    1.20          1.10
#
#            Bladder Cancer  Breast Cancer  Cervical Cancer  \
# Causes
# Belarus            676.27           2.21            17.05
# Mongolia          1062.04           6.30             4.43
# Russia             727.47           3.64            16.55
# Guatemala          732.92           7.09             4.10
# Slovenia           386.06           1.54            14.88
# ...                   ...            ...              ...
# Jordan             505.49           1.02            10.85
# Venezuela          623.36           7.07             7.41
# Singapore          317.40           0.99            13.72
# Armenia            603.67           2.62            11.44
# Colombia           434.82           4.23             8.06
#
#            Colon-Rectum Cancers  Congenital Anomalies  ...  \
# Causes                                                 ...
# Belarus                    2.85                282.35  ...
# Mongolia                   5.74                283.82  ...
# Russia                     3.54                204.50  ...
# Guatemala                  5.53                 85.26  ...
# Slovenia                   2.29                 57.54  ...
# ...                         ...                   ...  ...
# Jordan                     6.89                 98.90  ...
# Venezuela                  9.91                 99.32  ...
# Singapore                  1.92                 60.68  ...
# Armenia                    9.09                201.46  ...
# Colombia                   5.86                 76.09  ...
#
#            Global South Countries  Medical Bankruptcies by Country  \
# Causes
# Belarus                        No                        9432800.0
# Mongolia                      Yes                        3378078.0
# Russia                         No                      145805947.0
# Guatemala                     Yes                       18584039.0
# Slovenia                       No                        2078034.0
# ...                           ...                              ...
# Jordan                        Yes                       10300869.0
# Venezuela                     Yes                       29266991.0
# Singapore                     Yes                        5943546.0
# Armenia                        No                        2971966.0
# Colombia                      Yes                       51512762.0
#
#            Richest Countries in the World  Social Mobility by Country  \
# Causes
# Belarus                      6.131000e+10                   9432800.0
# Mongolia                     1.331000e+10                   3378078.0
# Russia                       1.480000e+12                 145805947.0
# Guatemala                    7.760000e+10                  18584039.0
# Slovenia                     5.355000e+10                   2078034.0
# ...                                   ...                         ...
# Jordan                       4.376000e+10                  10300869.0
# Venezuela                    4.726000e+10                  29266991.0
# Singapore                    3.452900e+11                   5943546.0
# Armenia                      1.264000e+10                   2971966.0
# Colombia                     2.704200e+11                  51512762.0
#
#            Countries by IQ - Average IQ by Country  Diabetes Rates by Country  \
# Causes
# Belarus                                     101.60                       0.06
# Mongolia                                     91.03                       0.07
# Russia                                       96.29                       0.06
# Guatemala                                    47.72                       0.13
# Slovenia                                     98.60                       0.06
# ...                                            ...                        ...
# Jordan                                       80.70                       0.15
# Venezuela                                    82.99                       0.10
# Singapore                                   105.89                       0.12
# Armenia                                      88.82                       0.06
# Colombia                                     83.13                       0.08
#
#            Health Care Costs by Country  Lactose Intolerance by Country  \
# Causes
# Belarus                       9432800.0                       9432800.0
# Mongolia                      3378078.0                       3378078.0
# Russia                      145805947.0                     145805947.0
# Guatemala                    18584039.0                      18584039.0
# Slovenia                      2078034.0                       2078034.0
# ...                                 ...                             ...
# Jordan                       10300869.0                      10300869.0
# Venezuela                    29266991.0                      29266991.0
# Singapore                     5943546.0                       5943546.0
# Armenia                       2971966.0                       2971966.0
# Colombia                     51512762.0                      51512762.0
#
#            Obesity Rates by Country  \
# Causes
# Belarus                       0.245
# Mongolia                      0.206
# Russia                        0.231
# Guatemala                     0.212
# Slovenia                      0.202
# ...                             ...
# Jordan                        0.355
# Venezuela                     0.256
# Singapore                     0.061
# Armenia                       0.202
# Colombia                      0.223
#
#                                         Zika Virus Countries
# Causes
# Belarus                       No mosquitoes that spread Zika
# Mongolia                      No mosquitoes that spread Zika
# Russia            With mosquitoes but no reported Zika cases
# Guatemala  Current or past transmission but no Zika outbreak
# Slovenia                      No mosquitoes that spread Zika
# ...                                                      ...
# Jordan                        No mosquitoes that spread Zika
# Venezuela  Current or past transmission but no Zika outbreak
# Singapore  Current or past transmission but no Zika outbreak
# Armenia                       No mosquitoes that spread Zika
# Colombia   Current or past transmission but no Zika outbreak
#
# [163 rows x 90 columns]

# %%
fig, axes = plt.subplots(1 ,figsize=(20,5))
less_sixty=(df_clean['Life Expectancy']).sort_values(ascending=False)
vector_i=less_sixty.iloc[0:15]
axes.bar(height=vector_i  ,x=vector_i.index)
less_sixty
# Out:
# Causes
# Japan           84.910
# Switzerland     84.112
# Singapore       83.934
# Spain           83.864
# Italy           83.856
#                  ...
# Somalia         58.060
# Sierra Leone    55.550
# Nigeria         55.436
# Lesotho         55.222
# Chad            54.896
# Name: Life Expectancy, Length: 163, dtype: float64

# %%
fig, axes = plt.subplots(1 ,figsize=(20,5))
High=(df_clean['Life Expectancy']).sort_values(ascending=True)
vector_i=High.iloc[0:15]
axes.bar(height=vector_i  ,x=vector_i.index)
vector_i
# Out:
# Causes
# Chad            54.896
# Lesotho         55.222
# Nigeria         55.436
# Sierra Leone    55.550
# Somalia         58.060
# South Sudan     58.476
# Cameroon        60.010
# Mali            60.174
# Mozambique      61.714
# Togo            61.810
# Angola          61.884
# Zimbabwe        61.894
# Guinea          62.320
# Burundi         62.372
# Benin           62.532
# Name: Life Expectancy, dtype: float64

# %%
value_Israel = df_clean.iloc[127]['Obesity Rates by Country']
value_Chad = df_clean.iloc[77]['Obesity Rates by Country']
df = pd.DataFrame({'Country':['Israel', 'Chad'], 'Obeisty_rate':[value_Israel,value_Chad]})
ax = df.plot.bar(x='Country', y='Obeisty_rate', rot=0)

# %%
fig, axes = plt.subplots(1 ,figsize=(20,5))
Suicide_rate=(df_clean['Suicide']).sort_values(ascending=False)
vector_i=Suicide_rate.iloc[50:60]
axes.pie(x=vector_i, labels=vector_i.index, autopct='%1.1f%%')
Suicide_rate
# Out:
# Causes
# Gabon            113.96
# Somalia          109.27
# Nigeria           99.13
# Liberia           89.99
# Angola            85.98
#                   ...
# United States      0.09
# Bahamas            0.08
# Netherlands        0.07
# Iceland            0.00
# Seychelles         0.00
# Name: Suicide, Length: 163, dtype: float64

# %%
fig, axes = plt.subplots(1 ,figsize=(20,5))
High=(df_clean['Obesity Rates by Country']).sort_values(ascending=False)
vector_i=High.iloc[0:15]
axes.bar(height=vector_i  ,x=vector_i.index)
vector_i
# Out:
# Causes
# Tonga            0.482
# Samoa            0.473
# Kiribati         0.460
# Kuwait           0.379
# United States    0.362
# Jordan           0.355
# Saudi Arabia     0.354
# Qatar            0.351
# Lebanon          0.337
# Libya            0.325
# Turkey           0.321
# Egypt            0.320
# Bahamas          0.316
# New Zealand      0.308
# Iraq             0.304
# Name: Obesity Rates by Country, dtype: float64

# %%
fig, axes = plt.subplots(1 ,figsize=(20,5))
High=(df_clean['Obesity Rates by Country']).sort_values(ascending=False)
vector_i=High.iloc[0:15]
axes.pie(x=vector_i, labels=vector_i.index, autopct='%1.1f%%')
vector_i
# Out:
# Causes
# Tonga            0.482
# Samoa            0.473
# Kiribati         0.460
# Kuwait           0.379
# United States    0.362
# Jordan           0.355
# Saudi Arabia     0.354
# Qatar            0.351
# Lebanon          0.337
# Libya            0.325
# Turkey           0.321
# Egypt            0.320
# Bahamas          0.316
# New Zealand      0.308
# Iraq             0.304
# Name: Obesity Rates by Country, dtype: float64

# %%
fig, axes = plt.subplots(1 ,figsize=(20,5))
High=(df_clean['Countries by IQ - Average IQ by Country']).sort_values(ascending=False)
vector_i=High.iloc[0:15]
axes.bar(height=vector_i  ,x=vector_i.index)
High
# Out:
# Causes
# Japan           106.48
# Singapore       105.89
# China           104.10
# South Korea     102.35
# Belarus         101.60
#                  ...
# Cape Verde       52.50
# Guatemala        47.72
# Sierra Leone     45.07
# Liberia          45.07
# Nepal            42.99
# Name: Countries by IQ - Average IQ by Country, Length: 163, dtype: float64

# %%
df_clean.iloc[128]
data_israel=['Countries by IQ - Average IQ by Country','Median Age ','Life Expectancy','Obesity Rates by Country']
data_value=[]
for i in data_israel:
    data_value.append(df_clean.iloc[128][i])

fig, axes = plt.subplots(1 ,figsize=(20,5))
axes.bar(height=data_value  ,x=data_israel)
# Out:
# <BarContainer object of 4 artists>

# %%
data_Chad=['Countries by IQ - Average IQ by Country','Median Age ','Life Expectancy','Obesity Rates by Country']
Chad_value=[]
for i in data_israel:
    Chad_value.append(df_clean.iloc[77][i])
    
fig, axes = plt.subplots(1 ,figsize=(20,5))
axes.bar(height=Chad_value  ,x=data_Chad)
#Compres israel between the lowest life expectancy that is chad by the data we scraped
# Out:
# <BarContainer object of 4 artists>

# %%
indexs=[127,77]
resons_check = [
         'Countries by IQ - Average IQ by Country','Birth Rates ','Suicide',
         'Life Expectancy']
ched_values=[]
israel_values=[]
for i in indexs:
    for j in resons_check:
        if(i==127):
            israel_values.append(df_clean.iloc[i][j])
        else:
            ched_values.append(df_clean.iloc[i][j])
  


           
df = pd.DataFrame({'Israel': israel_values,"Chad":ched_values}, index=resons_check)
ax = df.plot.barh()

# %%
indexs=[149,77]
resons_check = [
         'Countries by IQ - Average IQ by Country','Birth Rates ','Suicide',
         'Life Expectancy']
ched_values=[]
japan_values=[]
for i in indexs:
    for j in resons_check:
        if(i==149):
            japan_values.append(df_clean.iloc[i][j])
        else:
            ched_values.append(df_clean.iloc[i][j])
  


           
df = pd.DataFrame({'japan': japan_values,"Chad":ched_values}, index=resons_check)
ax = df.plot.barh()

# %%
indexs=[27,149]
resons_check = [
         'Countries by IQ - Average IQ by Country','Birth Rates ','Suicide',
         'Life Expectancy']
Japan_values=[]
USA_values=[]
for i in indexs:
    for j in resons_check:
        if(i==27):
            USA_values.append(df_clean.iloc[i][j])
        else:
            Japan_values.append(df_clean.iloc[i][j])
  


           
df = pd.DataFrame({'USA': USA_values,"Japan":Japan_values}, index=resons_check)
ax = df.plot.barh()
