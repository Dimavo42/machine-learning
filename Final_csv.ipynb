# %%
import pandas as pd
import os

csv1=r"C:\Users\Dima\Downloads\Jupyter_projectes\Untitled Folder 3\Finshed_Crawling_dataframes\crawling_1.csv"
csv2=r"C:\Users\Dima\Downloads\Jupyter_projectes\Untitled Folder 3\Finshed_Crawling_dataframes\crawling_2.csv"
csv3=r"C:\Users\Dima\Downloads\Jupyter_projectes\Untitled Folder 3\Finshed_Crawling_dataframes\crawling_3.csv"

# %%
csv1
# Out:
#                  Unnamed: 0  Belarus  Mongolia  Russia  Guatemala  Slovenia  \
# 0                   Alcohol   119.03    194.38  129.19      82.54    134.52
# 1               All Cancers    15.86     17.63   15.07      16.66      5.80
# 2     Alzheimers & Dementia     0.00      0.00    0.00       0.00      0.01
# 3                    Anemia     0.72      6.03    0.72       2.78      0.23
# 4                    Asthma     0.40      2.96    0.56       4.47      0.10
# 5              Birth Trauma     1.70      1.04    2.41       0.52      3.74
# 6            Bladder Cancer   676.27   1062.04  727.47     732.92    386.06
# 7                       NaN     1.46      9.43    3.67       8.86      0.89
# 8             Breast Cancer     2.21      6.30    3.64       7.09      1.54
# 9           Cervical Cancer    17.05      4.43   16.55       4.10     14.88
# 10     Colon-Rectum Cancers     2.85      5.74    3.54       5.53      2.29
# ...

# %%
csv2
# Out:
#                      Unnamed: 0          China United States      Germany  \
# 0      Current Account Balance       270,900.0    -469,400.0    301,400.0
# 1             GDP Growth Rates             6.1           2.2          0.6
# 2   Mobile Cellular Telephones   1,672,545,161   408,509,528  103,090,116
# 3                    Land Area     9,326,410.0   9,147,593.0    348,672.0
# 4            Coastline Lengths        14,500.0      19,924.0      2,389.0
# ..                          ...            ...           ...          ...
# 70           Crude Oil Imports       6,710,000     7,969,000    1,836,000
# 71                 Birth Rates           11.30         12.33         8.63
# 72      Education Expenditures             NaN           5.0          4.8
# 73             HIV/AIDS Deaths             NaN           NaN          500
# 74         HIV/AIDS Infections             NaN           NaN       87,000
#
#           Japan South Korea Netherlands      France   Hong Kong       Italy  \
# ...

# %%
csv3
# Out:
#                                            Unnamed: 0   China   India  \
# 0                                      Deaths per Day  30,373  28,279
# 1                                     Life Expectancy    77.3   70.19
# 2                    World Countries by National Debt  57.24%  75.11%
# 3               Most Dangerous Countries in the World   2.217   2.605
# 4                  Most Dangerous Countries For Women  444.55  541.25
# ..                                                ...     ...     ...
# 135                                     EEA Countries     NaN     NaN
# 136                                Tax-Free Countries     NaN     NaN
# 137                     Traditional Economy Countries     NaN     NaN
# 138  EFTA Countries | European Free Trade Association     NaN     NaN
# 139                   Countries Without Central Banks     NaN     NaN
#
#     United States Indonesia Pakistan Nigeria  Brazil Bangladesh  Russia  ...  \
# ...

# %%
df = pd.concat(map(pd.read_csv, [csv1, csv2,csv3]), ignore_index=True)
## Mereging the CSV into one CSV And creating a df
df.to_csv('final_df.csv', encoding='utf-8')
df
# Out:
#                                            Unnamed: 0 Belarus Mongolia  \
# 0                                             Alcohol  119.03   194.38
# 1                                         All Cancers   15.86    17.63
# 2                               Alzheimers & Dementia       0        0
# 3                                              Anemia    0.72     6.03
# 4                                              Asthma     0.4     2.96
# ..                                                ...     ...      ...
# 262                                     EEA Countries     NaN      NaN
# 263                                Tax-Free Countries     NaN      NaN
# 264                     Traditional Economy Countries     NaN      NaN
# 265  EFTA Countries | European Free Trade Association     NaN      NaN
# 266                   Countries Without Central Banks     NaN      NaN
#
#      Russia Guatemala   Slovenia El Salvador Ukraine      Poland     Latvia  \
# ...
